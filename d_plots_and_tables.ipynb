# %%
import warnings

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd
import seaborn as sns

warnings.filterwarnings("ignore")

#!pip install seaborn --upgrade

# %%
def plot(df, variable="total_cost"):
    feature_title = {"total_cost": "total cost"}

    if variable not in feature_title.keys():
        raise NameError(
            "Variable " + variable + " is not valid.\n"
            "The variable must be one of: " +
            ", ".join(list(feature_title.keys())),
        )

    def vertical_mean_line(x, **kwargs):
        plt.axvline(x.mean(), linestyle="--", color="blue", linewidth=3)

    strategy = df.strategy[0]
    people = 1000
    model_parameters = pd.read_pickle(
        filepath_or_buffer="data/model_parameters.pkl")
    if strategy == 4:
        g = sns.displot(df, x=variable)
        g.map(vertical_mean_line, variable)
        # g.refline(x=df[variable].mean(), color="blue", lw=3)
        g.refline(x=people * 100, color="red", lw=3)
        plt.show()
    else:
        g = sns.displot(df, x=variable, col="prob_symp_more_5d")
        # g.map(vertical_mean_line, variable)
        # g.refline(x=df[variable].mean(), color="blue", lw=3)
        # g.refline(x=people * 100, color="red", lw=3)
        plt.show()

# %%
# def plot(df, variable="total_cost"):
#     feature_title = {"total_cost": "total cost"}

#     if variable not in feature_title.keys():
#         raise NameError(
#             "Variable " + variable + " is not valid.\n"
#             "The variable must be one of: " + ", ".join(list(feature_title.keys())),
#         )

#     strategy = df.strategy[0]

#     if strategy == 4:
#         display(
#             ggplot(df)
#             + geom_histogram(aes(variable))
#             + geom_vline(aes(xintercept=df[variable].mean()), color="red")
#             + labs(title="Distribution of " + feature_title[variable])
#             + theme_classic()
#         )
#     else:
#         dfv2 = df.copy()
#         dfv2["prob_symp_more_5d"] = [
#             "prob_symp_more_5d: " + str(k) for k in df["prob_symp_more_5d"]
#         ]
#         df_stats = dfv2.groupby("prob_symp_more_5d", as_index=False).agg(
#             media=(variable, "mean")
#         )
#         display(
#             ggplot(dfv2)
#             + geom_histogram(aes(variable))
#             + geom_vline(df_stats, aes(xintercept="media", color="prob_symp_more_5d"))
#             + labs(title="Distribution of " + feature_title[variable])
#             + facet_wrap("~prob_symp_more_5d")
#             + theme_classic()
#         )

# %%
df_strategy_1 = pd.read_pickle(filepath_or_buffer="data/df_strategy_1.pkl")
df_strategy_2 = pd.read_pickle(filepath_or_buffer="data/df_strategy_2.pkl")
df_strategy_3 = pd.read_pickle(filepath_or_buffer="data/df_strategy_3.pkl")
df_strategy_4 = pd.read_pickle(filepath_or_buffer="data/df_strategy_4.pkl")
df_all = pd.concat([df_strategy_1, df_strategy_2,
                   df_strategy_3, df_strategy_4])

# %%
plot(df=df_strategy_1)

# %%
plot(df=df_strategy_1)

# %%
plot(df=df_strategy_2)

# %%
plot(df=df_strategy_3)

# %%
plot(df=df_strategy_4)

# %%
df_all
# Out:
#       strategy  prevalence  people  people_high_risk  people_low_risk  \
# 0            1    0.269096    1000               362              638
# 1            1    0.269096    1000               362              638
# 2            1    0.269096    1000               362              638
# 3            1    0.269096    1000               390              610
# 4            1    0.269096    1000               390              610
# ...        ...         ...     ...               ...              ...
# 2995         4    0.269096    1000               379              612
# 2996         4    0.269096    1000               387              606
# 2997         4    0.269096    1000               392              602
# 2998         4    0.269096    1000               352              629
# 2999         4    0.269096    1000               365              627
#
#       sens_model  spec_model  sens_ag_test  spec_ag_test  prob_symp_less_5d  \
# 0       0.796296    0.767918           0.8          0.95               0.75
# 1       0.796296    0.767918           0.8          0.95               0.50
# 2       0.796296    0.767918           0.8          0.95               0.25
# 3       0.796296    0.767918           0.8          0.95               0.75
# 4       0.796296    0.767918           0.8          0.95               0.50
# ...          ...         ...           ...           ...                ...
# 2995    0.796296    0.767918           0.8          0.95               0.50
# 2996    0.796296    0.767918           0.8          0.95               0.25
# 2997    0.796296    0.767918           0.8          0.95               0.75
# 2998    0.796296    0.767918           0.8          0.95               0.50
# 2999    0.796296    0.767918           0.8          0.95               0.25
#
#       ...  total_cost_alt  total_cost_pcr  total_cost  stock_capacity  \
# 0     ...           13850         20900.0     34750.0     1398.561151
# 1     ...            9550         24500.0     34050.0     1280.469897
# 2     ...            4850         30400.0     35250.0     1137.588652
# 3     ...           15000         21000.0     36000.0     1416.666667
# 4     ...            9100         28400.0     37500.0     1242.666667
# ...   ...             ...             ...         ...             ...
# 2995  ...           44300           900.0     45200.0     2683.628319
# 2996  ...           43650           700.0     44350.0     2714.768884
# 2997  ...           43740           600.0     44340.0     2733.423545
# 2998  ...           44260          1900.0     46160.0     2612.651646
# 2999  ...           44460           800.0     45260.0     2662.395051
#
#       efficiency  nsimul  people_first_responder  sens_lamp_test  \
# 0     776.978417       1                     NaN             NaN
# 1     743.024963       1                     NaN             NaN
# 2     655.319149       1                     NaN             NaN
# 3     811.111111       2                     NaN             NaN
# 4     760.000000       2                     NaN             NaN
# ...          ...     ...                     ...             ...
# 2995  736.725664     999                     9.0            0.95
# 2996  698.985344     999                     7.0            0.95
# 2997  744.248985    1000                     6.0            0.95
# 2998  673.743501    1000                    19.0            0.95
# 2999  722.492267    1000                     8.0            0.95
#
#       spec_lamp_test  prob_model_first_responder_pcr,
# 0                NaN                              NaN
# 1                NaN                              NaN
# 2                NaN                              NaN
# 3                NaN                              NaN
# 4                NaN                              NaN
# ...              ...                              ...
# 2995            0.95                             0.01
# 2996            0.95                             0.01
# 2997            0.95                             0.01
# 2998            0.95                             0.01
# 2999            0.95                             0.01
#
# [12000 rows x 26 columns]

# %%
# g.map(vertical_mean_line, "total_cost")

# g = sns.FacetGrid(data=df_all, row="prob_symp_more_5d")
# g.map(sns.histplot, "total_cost")

df_all["total_cost_k"] = df_all["total_cost"] / 1000


h = 10
w = h * 1.618
# Create plot using seaborn
sns.set(style="ticks")
sns.set_context("paper", font_scale=1.5)
plt.figure(figsize=(w, h))  # set the figure size


g = sns.displot(
    df_all,
    x="total_cost_k",
    col="prob_symp_more_5d",
    hue="strategy",
    kind="kde",
    fill=True,
    # binwidth=1000,
    # stat="probability",
    palette="tab10",
    height=3,
    aspect=1,
)

# plt.axvline(x=1000 * 100, linestyle="--", color="red", linewidth=2)
# g.map(vertical_mean_line, variable)
# # g.refline(x=df[variable].mean(), color="blue", lw=3)
# g.refline(x=1000 * 100, color=None, linewidth=3)
# plt.xscale("log")
g.set_titles("{col_name:.0%}", pad=2)
# g.set_titles("{col_name}: {col_var:.0%}", pad=2)

g.set_axis_labels("Total Cost", "Probability")
for ax in g.axes.flat:
    ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}"))

plt.subplots_adjust(hspace=1, wspace=0.2)
g.fig.suptitle("Distribution of total cost", y=1.0005)
g.axes[0, 0].set_xlabel("")
g.axes[0, 0].set_xticks([30, 40, 50, 60, 70, 80])
# g.axes[0, 0].set_xticklabels(g.axes[0,0].get_xticks(),rotation=-45)
# g.axes[0, 1].set_xticklabels(g.axes[0,1].get_xticks(),rotation=-45)
# g.axes[0, 2].set_xticklabels(g.axes[0,2].get_xticks(),rotation=-45)
g.axes[0, 1].set_xlabel("Total cost (in thousands)")
g.axes[0, 2].set_xlabel("")
# g.fig.text(
#     0.6,
#     -0.1,
#     """* Each facet assumes the indicated population
#    fraction with symptoms lasting 5 days or more.""",
#     ha="left",
#     fontsize=11,
# )


# So that axis show
# plt.tight_layout()

plt.savefig("img/hist_total_cost_strategies.pdf", bbox_inches="tight")
plt.show()

# %%
g.axes[0, 0].get_xticks()
# Out:
# array([30, 40, 50, 60, 70, 80])

# %%
# g.map(vertical_mean_line, "total_cost")

# g = sns.FacetGrid(data=df_all, row="prob_symp_more_5d")
# g.map(sns.histplot, "total_cost")


h = 10
w = h * 1.618
# Create plot using seaborn
sns.set(style="ticks")
sns.set_context("paper", font_scale=1.5)
plt.figure(figsize=(w, h))  # set the figure size

g = sns.displot(
    df_all,
    x="number_test_per_person",
    col="prob_symp_more_5d",
    hue="strategy",
    kind="kde",
    fill=True,
    # binwidth=1000,
    # stat="probability",
    palette="tab10",
    height=3,
    aspect=1,
)
g.set(
    xlabel="Number of tests per person",
    ylabel="Probability",
)


# plt.axvline(x=1000 * 100, linestyle="--", color="red", linewidth=2)
# g.map(vertical_mean_line, variable)
# # g.refline(x=df[variable].mean(), color="blue", lw=3)
# g.refline(x=1000 * 100, color=None, linewidth=3)
# plt.xscale("log")
# use this argument literally
plt.subplots_adjust(hspace=0.1, wspace=0.2)
g.set_titles("{col_name:.0%}", pad=2)
g.set_axis_labels("Number of tests per person", "Count")
g.fig.suptitle("Distribution of number of tests per person", y=1.0005)
g.axes[0, 0].set_xlabel("")
g.axes[0, 1].set_xlabel("Number of tests per person")
g.axes[0, 2].set_xlabel("")

# g.fig.text(
#     0.6,
#     -0.1,
#     """* Each facet assumes the indicated population
#    fraction with symptoms lasting 5 days or more.""",
#     ha="left",
#     fontsize=11,
# )

# So that axis show
# plt.tight_layout()
plt.savefig("img/hist_test_per_person_strategies.pdf", bbox_inches="tight")
plt.show()

# %%
# g.map(vertical_mean_line, "total_cost")

# g = sns.FacetGrid(data=df_all, row="prob_symp_more_5d")
# g.map(sns.histplot, "total_cost")

h = 10
w = h * 1.618
# Create plot using seaborn
sns.set(style="ticks")
sns.set_context("paper", font_scale=1.5)
plt.figure(figsize=(w, h))  # set the figure size

g = sns.displot(
    df_all,
    x="number_positive_reported",
    col="prob_symp_more_5d",
    hue="strategy",
    # binwidth=0.01,
    # stat="probability",
    palette="tab10",
    height=3,
    aspect=1,
    kind="kde",
    fill=True
    # multiple="dodge",
)

# plt.axvline(x=1000 * 100, linestyle="--", color="red", linewidth=2)
# g.map(vertical_mean_line, variable)
# # g.refline(x=df[variable].mean(), color="blue", lw=3)
# g.refline(x=1000 * 100, color=None, linewidth=3)
# plt.xscale("log")
# for ax in g.axes.flat:
#     ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}"))
plt.subplots_adjust(hspace=0.1, wspace=0.2)
g.set_titles("{col_name:.0%}", pad=2)  # use this argument literally
g.set_axis_labels("Number of tests per person", "Probability", fontsize=13)
g.fig.suptitle("Distribution of number of positives", y=1.0005, fontsize=13)
g.axes[0, 0].set_xlabel("")
g.axes[0, 1].set_xlabel("Number of positives")
g.axes[0, 2].set_xlabel("")

# g.fig.text(
#     0.6,
#     -0.1,
#     """* Each facet assumes the indicated population
#    fraction with symptoms lasting 5 days or more.""",
#     ha="left",
#     fontsize=11,
# )

# So that axis show
# plt.tight_layout()
plt.savefig("img/hist_positives_strategies.pdf", bbox_inches="tight")
plt.show()

# %%
df_all["stock_capacity_k"] = df_all["stock_capacity"] / 1000

h = 10
w = h * 1.618
# Create plot using seaborn
sns.set(style="ticks")
sns.set_context("paper", font_scale=1.5)
plt.figure(figsize=(w, h))  # set the figure size

g = sns.displot(
    df_all,
    x="stock_capacity_k",
    y="efficiency",
    col="prob_symp_more_5d",
    hue="strategy",
    # binwidth=0.01,
    # stat="probability",
    palette="tab10",
    height=3,
    aspect=1,
    kind="kde",
    fill=True,
    # multiple="dodge",
)


# plt.axvline(x=1000 * 100, linestyle="--", color="red", linewidth=2)
# g.map(vertical_mean_line, variable)
# # g.refline(x=df[variable].mean(), color="blue", lw=3)
# g.refline(x=1000 * 100, color=None, linewidth=3)
# plt.xscale("log")
# for ax in g.axes.flat:
#     ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}"))

# g.fig.suptitle("Proportion of +5 days symptoms", y=1.0005, fontsize=13)
plt.subplots_adjust(hspace=0.1, wspace=0.2)
g.set_titles("{col_name:.0%}", pad=2)  # use this argument literally
g.set_axis_labels("Stock Capacity", "Efficiency")
g.fig.suptitle("Distribution of efficiency vs stock capacity", y=1.0005)
g.axes[0, 0].set_xlabel("")
g.axes[0, 1].set_xlabel("Stock Capacity (in thousands)")
g.axes[0, 2].set_xlabel("")
# for ax in g.axes.flat:
#     ax.set_xticks(range(1000, 3001, 250))
# ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}"))

# g.set_xticklabels(rotation=45)

# g.fig.text(
#     0.6,
#     -0.2,
#     """* Each facet assumes the indicated population
#    fraction with symptoms lasting 5 days or more.""",
#     ha="left",
#     fontsize=11,
# )
# So that axis show
# plt.tight_layout()
plt.savefig("img/hist_stock_capacity_vs_efficiency_strategies.pdf",
            bbox_inches="tight")
plt.show()
