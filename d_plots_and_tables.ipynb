# %%
import warnings

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd
import seaborn as sns

warnings.filterwarnings("ignore")

#!pip install seaborn --upgrade

# %%
def plot(df, variable="total_cost"):
    feature_title = {"total_cost": "total cost"}

    if variable not in feature_title.keys():
        raise NameError(
            "Variable " + variable + " is not valid.\n"
            "The variable must be one of: " +
            ", ".join(list(feature_title.keys())),
        )

    def vertical_mean_line(x, **kwargs):
        plt.axvline(x.mean(), linestyle="--", color="blue", linewidth=3)

    strategy = df.strategy[0]
    people = 1000
    model_parameters = pd.read_pickle(
        filepath_or_buffer="data/model_parameters.pkl")
    if strategy == 4:
        g = sns.displot(df, x=variable)
        g.map(vertical_mean_line, variable)
        # g.refline(x=df[variable].mean(), color="blue", lw=3)
        g.refline(x=people * 100, color="red", lw=3)
        plt.show()
    else:
        g = sns.displot(df, x=variable, col="prob_symp_more_5d")
        # g.map(vertical_mean_line, variable)
        # g.refline(x=df[variable].mean(), color="blue", lw=3)
        # g.refline(x=people * 100, color="red", lw=3)
        plt.show()

# %%
# def plot(df, variable="total_cost"):
#     feature_title = {"total_cost": "total cost"}

#     if variable not in feature_title.keys():
#         raise NameError(
#             "Variable " + variable + " is not valid.\n"
#             "The variable must be one of: " + ", ".join(list(feature_title.keys())),
#         )

#     strategy = df.strategy[0]

#     if strategy == 4:
#         display(
#             ggplot(df)
#             + geom_histogram(aes(variable))
#             + geom_vline(aes(xintercept=df[variable].mean()), color="red")
#             + labs(title="Distribution of " + feature_title[variable])
#             + theme_classic()
#         )
#     else:
#         dfv2 = df.copy()
#         dfv2["prob_symp_more_5d"] = [
#             "prob_symp_more_5d: " + str(k) for k in df["prob_symp_more_5d"]
#         ]
#         df_stats = dfv2.groupby("prob_symp_more_5d", as_index=False).agg(
#             media=(variable, "mean")
#         )
#         display(
#             ggplot(dfv2)
#             + geom_histogram(aes(variable))
#             + geom_vline(df_stats, aes(xintercept="media", color="prob_symp_more_5d"))
#             + labs(title="Distribution of " + feature_title[variable])
#             + facet_wrap("~prob_symp_more_5d")
#             + theme_classic()
#         )

# %%
df_strategy_1 = pd.read_pickle(filepath_or_buffer="data/df_strategy_1.pkl")
df_strategy_2 = pd.read_pickle(filepath_or_buffer="data/df_strategy_2.pkl")
df_strategy_3 = pd.read_pickle(filepath_or_buffer="data/df_strategy_3.pkl")
df_strategy_4 = pd.read_pickle(filepath_or_buffer="data/df_strategy_4.pkl")
df_all = pd.concat([df_strategy_1, df_strategy_2,
                   df_strategy_3, df_strategy_4])

# %%
plot(df=df_strategy_1)

# %%
plot(df=df_strategy_1)

# %%
plot(df=df_strategy_2)

# %%
plot(df=df_strategy_3)

# %%
plot(df=df_strategy_4)

# %%
df_all
# Out:
#       strategy  prevalence  people  people_high_risk  people_low_risk  \
# 0            1    0.269096    1000               318              682
# 1            1    0.269096    1000               318              682
# 2            1    0.269096    1000               318              682
# 3            1    0.269096    1000               350              650
# 4            1    0.269096    1000               350              650
# ...        ...         ...     ...               ...              ...
# 2995         4    0.269096    1000               347              641
# 2996         4    0.269096    1000               341              651
# 2997         4    0.269096    1000               316              667
# 2998         4    0.269096    1000               336              658
# 2999         4    0.269096    1000               330              658
#
#       sens_model  spec_model  sens_ag_test  spec_ag_test  prob_symp_less_5d  \
# 0           0.75    0.812287           0.8          0.95               0.75
# 1           0.75    0.812287           0.8          0.95               0.50
# 2           0.75    0.812287           0.8          0.95               0.25
# 3           0.75    0.812287           0.8          0.95               0.75
# 4           0.75    0.812287           0.8          0.95               0.50
# ...          ...         ...           ...           ...                ...
# 2995        0.75    0.812287           0.8          0.95               0.50
# 2996        0.75    0.812287           0.8          0.95               0.25
# 2997        0.75    0.812287           0.8          0.95               0.75
# 2998        0.75    0.812287           0.8          0.95               0.50
# 2999        0.75    0.812287           0.8          0.95               0.25
#
#       ...  total_cost_alt  total_cost_pcr  total_cost  stock_capacity  \
# 0     ...           12100         17700.0     29800.0     1406.040268
# 1     ...            7750         23400.0     31150.0     1248.796148
# 2     ...            3600         27000.0     30600.0     1117.647059
# 3     ...           13300         20700.0     34000.0     1391.176471
# 4     ...            8950         24800.0     33750.0     1265.185185
# ...   ...             ...             ...         ...             ...
# 2995  ...           44220          1200.0     45420.0     2608.982827
# 2996  ...           45030           800.0     45830.0     2596.552477
# 2997  ...           45380          1700.0     47080.0     2497.875956
# 2998  ...           45710           600.0     46310.0     2567.480026
# 2999  ...           44590          1200.0     45790.0     2566.062459
#
#       efficiency  nsimul  people_first_responder  sens_lamp_test  \
# 0     872.483221       1                     NaN             NaN
# 1     776.886035       1                     NaN             NaN
# 2     718.954248       1                     NaN             NaN
# 3     850.000000       2                     NaN             NaN
# 4     761.481481       2                     NaN             NaN
# ...          ...     ...                     ...             ...
# 2995  684.720387     999                    12.0            0.95
# 2996  678.594807     999                     8.0            0.95
# 2997  626.593033    1000                    17.0            0.95
# 2998  626.214640    1000                     6.0            0.95
# 2999  642.061585    1000                    12.0            0.95
#
#       spec_lamp_test  prob_model_first_responder_pcr,
# 0                NaN                              NaN
# 1                NaN                              NaN
# 2                NaN                              NaN
# 3                NaN                              NaN
# 4                NaN                              NaN
# ...              ...                              ...
# 2995            0.95                             0.01
# 2996            0.95                             0.01
# 2997            0.95                             0.01
# 2998            0.95                             0.01
# 2999            0.95                             0.01
#
# [12000 rows x 26 columns]

# %%
# g.map(vertical_mean_line, "total_cost")

# g = sns.FacetGrid(data=df_all, row="prob_symp_more_5d")
# g.map(sns.histplot, "total_cost")


g = sns.displot(
    df_all,
    x="total_cost",
    col="prob_symp_more_5d",
    hue="strategy",
    kind="kde",
    fill=True,
    # binwidth=1000,
    # stat="probability",
    palette="colorblind",
    height=3,
    aspect=1,
)

# plt.axvline(x=1000 * 100, linestyle="--", color="red", linewidth=2)
# g.map(vertical_mean_line, variable)
# # g.refline(x=df[variable].mean(), color="blue", lw=3)
# g.refline(x=1000 * 100, color=None, linewidth=3)
# plt.xscale("log")
g.set_titles("{col_name}", pad=2)  # use this argument literally
g.set_axis_labels("Total Cost", "Probability", fontsize=13)
for ax in g.axes.flat:
    ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}"))
g.fig.suptitle("prob_symp_more_5d = ", y=1.0005, fontsize=13)
g.axes[0, 0].set_xlabel("")
g.axes[0, 1].set_xlabel("Total cost")
g.axes[0, 2].set_xlabel("")
# So that axis show
# plt.tight_layout()
plt.savefig("img/hist_total_cost_strategies.pdf")
plt.show()

# %%
# g.map(vertical_mean_line, "total_cost")

# g = sns.FacetGrid(data=df_all, row="prob_symp_more_5d")
# g.map(sns.histplot, "total_cost")


g = sns.displot(
    df_all,
    x="number_test_per_person",
    col="prob_symp_more_5d",
    hue="strategy",
    # binwidth=0.01,
    # stat="probability",
    palette="colorblind",
    height=3,
    aspect=1,
    kind="kde",
    fill=True
    # multiple="dodge",
)
g.set(
    xlabel="Number of tests per person",
    ylabel="Probability",
)


# plt.axvline(x=1000 * 100, linestyle="--", color="red", linewidth=2)
# g.map(vertical_mean_line, variable)
# # g.refline(x=df[variable].mean(), color="blue", lw=3)
# g.refline(x=1000 * 100, color=None, linewidth=3)
# plt.xscale("log")
g.set_titles("{col_name}", pad=2)  # use this argument literally
g.set_axis_labels("Number of tests per person", "Count", fontsize=13)
# g.fig.suptitle("prob_symp_more_5d = ", y=1.0005, fontsize=13)
g.axes[0, 0].set_xlabel("")
g.axes[0, 1].set_xlabel("Number of tests per person")
g.axes[0, 2].set_xlabel("")
# So that axis show
# plt.tight_layout()
plt.savefig("img/hist_test_per_person_strategies.pdf")
plt.show()

# %%
# g.map(vertical_mean_line, "total_cost")

# g = sns.FacetGrid(data=df_all, row="prob_symp_more_5d")
# g.map(sns.histplot, "total_cost")


g = sns.displot(
    df_all,
    x="number_positive_reported",
    col="prob_symp_more_5d",
    hue="strategy",
    # binwidth=0.01,
    # stat="probability",
    palette="colorblind",
    height=3,
    aspect=1,
    kind="kde",
    fill=True
    # multiple="dodge",
)

# plt.axvline(x=1000 * 100, linestyle="--", color="red", linewidth=2)
# g.map(vertical_mean_line, variable)
# # g.refline(x=df[variable].mean(), color="blue", lw=3)
# g.refline(x=1000 * 100, color=None, linewidth=3)
# plt.xscale("log")
# for ax in g.axes.flat:
#     ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}"))
g.set_titles("{col_name}", pad=2)  # use this argument literally
g.set_axis_labels("Number of tests per person", "Probability", fontsize=13)
g.fig.suptitle("prob_symp_more_5d = ", y=1.0005, fontsize=13)
g.axes[0, 0].set_xlabel("")
g.axes[0, 1].set_xlabel("Number of positives")
g.axes[0, 2].set_xlabel("")


# So that axis show
# plt.tight_layout()
plt.savefig("img/hist_positives_strategies.pdf")
plt.show()

# %%
g = sns.displot(
    df_all,
    x="stock_capacity",
    y="efficiency",
    col="prob_symp_more_5d",
    hue="strategy",
    # binwidth=0.01,
    # stat="probability",
    palette="colorblind",
    height=3,
    aspect=1,
    kind="kde",
    fill=True,
    # multiple="dodge",
)


# plt.axvline(x=1000 * 100, linestyle="--", color="red", linewidth=2)
# g.map(vertical_mean_line, variable)
# # g.refline(x=df[variable].mean(), color="blue", lw=3)
# g.refline(x=1000 * 100, color=None, linewidth=3)
# plt.xscale("log")
# for ax in g.axes.flat:
#     ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}"))

# g.fig.suptitle("Proportion of +5 days symptoms", y=1.0005, fontsize=13)
g.set_titles("{col_name}", pad=2)  # use this argument literally
g.set_axis_labels("Stock Capacity", "Efficiency", fontsize=13)
g.axes[0, 0].set_xlabel("")
g.axes[0, 1].set_xlabel("Stock Capacity")
g.axes[0, 2].set_xlabel("")
for ax in g.axes.flat:
    ax.set_xticks(range(1000, 3001, 250))
    # ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}"))

g.set_xticklabels(rotation=45)
# So that axis show
# plt.tight_layout()
plt.savefig("img/hist_stock_capacity_vs_efficiency_strategies.pdf")
plt.show()

# %%
range(0, 3000, 500)
# Out:
# range(0, 3000, 500)
